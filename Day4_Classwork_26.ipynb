# %%
#Q1-When X=4 and y =3, perform the bitwise operations & (and), |(or)
#& | ^ ~ << >>
x=4 #0100
y=3 #0011
print(bin(x))
print(bin(y))
print("Bitwise and operation", x&y) #0000
print("Bitwise or operation", x|y)  #0111
# Out:
# 0b100
# 0b11
# Bitwise and operation 0
# Bitwise or operation 7

# %%
#Q2 -Write a program to display multiplication table of 12,  refer the sample program output inline

for i in range(1,11):
    print(str(12),"*",str(i)," = ",12*i)
# Out:
# 12 * 1  =  12
# 12 * 2  =  24
# 12 * 3  =  36
# 12 * 4  =  48
# 12 * 5  =  60
# 12 * 6  =  72
# 12 * 7  =  84
# 12 * 8  =  96
# 12 * 9  =  108
# 12 * 10  =  120

# %%
'''
   Q3.Write a program that takes marks of 5 subjects and display the grade, refer the sample program output Inline
Note – Use the inline Business logic while calculating grades:
If the average is greater than 90, “Grade: A” is printed.
If the average is in between 80 and 90, “Grade: B” is printed.
If the average is in between 70 and 80, “Grade: C” is printed.
If the average is in between 60 and 70, “Grade: D” is printed.
If the average is anything below 60, “Grade: F” is printed.
'''
sub1 = int(input("Enter marks of the first subject : "))
sub2 = int(input("Enter marks of the 2nd subject : "))
sub3 = int(input("Enter marks of the 3rd subject : "))
sub4 = int(input("Enter marks of the 4th subject : "))
sub5 = int(input("Enter marks of the 5th subject : "))
avgOfMarks=(sub1+sub2+sub3+sub4+sub5)/5
if(avgOfMarks >= 90):
    print("Grade: A")
elif(avgOfMarks>=80 and avgOfMarks<90):
    print("Grade: B")
elif(avgOfMarks>=70 and avgOfMarks<80):
    print("Grade: C")
elif(avgOfMarks>=60 and avgOfMarks<70):
    print("Grade: D")
else:
    print("Grade: F")
# Out:
# Enter marks of the first subject :  50
# Enter marks of the 2nd subject :  60
# Enter marks of the 3rd subject :  80
# Enter marks of the 4th subject :  90
# Enter marks of the 5th subject :  100
# Grade: C

# %%
#Q4: Write a program to demonstrate the usage of sample calculator
while(True):
    print("Select the operation")
    print("1. Add")
    print("2. Subtract")
    print("3. Multiply")
    print("4. Division")
    print("5. Quit")
    print("Enter your Choice (1/2/3/4/5)")
    choice =input()
    if choice in ("1","2","3","4"):
        num1 = int(input("Enter first number :"))
        num2 = int(input("Enter second number :"))
        if choice == "1":
            result=num1+num2
            print("Addition Result :", result)
        elif choice == "2":
            result =num1-num2
            print("Subtraction Result :", result)
        elif choice == "3":
            result = num1*num2
            print("Multiplication result:", result)
        elif choice == "4":
            result = num1/num2
            print("Division result:", result)
    elif choice =="5":
            print("Thank you for using calculator")
            break
        
    else:
        print("enter valid choice")
# Out:
# Select the operation
# 1. Add
# 2. Subtract
# 3. Multiply
# 4. Division
# 5. Quit
# Enter your Choice (1/2/3/4/5)
#  4
# Enter first number : 15
# Enter second number : 10
# Division result: 1.5
# Select the operation
# 1. Add
# 2. Subtract
# 3. Multiply
# 4. Division
# 5. Quit
# Enter your Choice (1/2/3/4/5)
#  5
# Thank you for using calculator

# %%
#1.	Write a python program to check if the input character is an alphabet or not
ch = input("Enter a character: ")
if((ch>='a' and ch<= 'z') or (ch>='A' and ch<='Z')):
    print(ch, "is an Alphabet")
else:
    print(ch, "is not an Alphabet")
# Out:
# Enter a character:  123213
# 123213 is not an Alphabet

# %%
#2.	Python program to check whether the number entered by user is even or odd, 
num = int(input("Enter any number: "))
flag = num%2
if flag == 0:
    print(num, "is an even number")
elif flag == 1:
    print(num, "is an odd number")
else:
    print("Error, Invalid input")
# Out:
# Enter any number:  1
# 1 is an odd number

# %%
#Python program to swap elements
mylist=[1,2,3,4,5]
print("Before Swapping", mylist)
size= len(mylist)
temp=mylist[0] #First element is fetch or assigned to temp variable
mylist[0] = mylist[size-1] #Last element is assigned to 1st postion
mylist[size-1]= temp # temp or first element to last position
print("after swapping", mylist)
# Out:
# Before Swapping [1, 2, 3, 4, 5]
# after swapping [5, 2, 3, 4, 1]

# %%
#Python program to swap elements
mylist = [1, 2, 3, 4, 5]
print(f"Original list: {mylist}")

n = len(mylist)
for i in range(n // 2):
    # Swap elements at index i and index n-1-i (which is also mylist[-(i+1)])
    mylist[i], mylist[n - 1 - i] = mylist[n - 1 - i], mylist[i]

print(f"Swapped list (reversed): {mylist}")
# Out:
# Original list: [1, 2, 3, 4, 5]
# Swapped list (reversed): [5, 4, 3, 2, 1]

# %%
#2.	Write a program to sum all the list elements
list=[1,2,3,4,5,6,7,8]
total =0
print("Input List", list)
for x in list:
    total= total +x
print("total of List items", total)
# Out:
# Input List [1, 2, 3, 4, 5, 6, 7, 8]
# total of List items 36

# %%
#3. Write a program to find size of a sample list and  tuple, also find the time 
#taken to initialize a list and tuple 100000 times. 
import sys
import timeit
mylist=[1,2,3,4,5,6,7,8,8,9,9,10]
mytuple = (1,2,3,4,5,6,7,8,8,9,9,10)
print("mylist :", mylist)
print("mytuple", mytuple)
print("size of mylist" , sys.getsizeof(mylist)) #getsizeof() return the memory size of an object in bytes
print("size of mytuple" , sys.getsizeof(mytuple))#getsizeof() return the memory size of an object in bytes

listtime = timeit.timeit(stmt="[1,2,3,4,5,6,7,8,8,9,9,10]", number= 100000)
tupletime = timeit.timeit(stmt="(1,2,3,4,5,6,7,8,8,9,9,10)", number= 100000)
print("time taken to execute mylist statement 100000 times", listtime)
print("time take to execute mytuple statement 100000 times" , tupletime)
# Out:
# mylist : [1, 2, 3, 4, 5, 6, 7, 8, 8, 9, 9, 10]
# mytuple (1, 2, 3, 4, 5, 6, 7, 8, 8, 9, 9, 10)
# size of mylist 152
# size of mytuple 136
# time taken to execulte mylist statement 100000 times 0.004705200030002743
# time take to execute mytuple statement 100000 times 0.0009609000408090651

# %%
#4.	Write a program to demonstrate the set operation, union, intersection, difference and subset, 
A={1,2,3,4,5}
B={4,5,6,7,8}
print("Set A : ", A)
print("Set B :", B)
print("Union Result : ", A.union(B))
print("Intersection Result : " , A.intersection(B))
print("Difference Result : " , A.difference(B))
print("Subset Result : " , A.issubset(B))
# Out:
# Set A :  {1, 2, 3, 4, 5}
# Set B : {4, 5, 6, 7, 8}
# Union Result :  {1, 2, 3, 4, 5, 6, 7, 8}
# Intersection Result :  {4, 5}
# Difference Result :  {1, 2, 3}
# Subset Result :  False

# %%
#5.	Write a Python script to add a key to a dictionary.
#Sample Dictionary : {'id': '59912', 'name': 'AAA', 'location': 'bengaluru'}
#After update, 
#Expected Result :  {'id': '59912', 'name': 'AAA', 'location': 'bengaluru', 'Salary': 500000)
# 	Iterate over dictionary and display the key and values
mydict = {"id" :"59912",
          "name":"AAA",
          "location": "bengaluru"
         }
print("before update" , mydict)
mydict.update({"Salary":899999})
print("after update", mydict)
#print mydict values using loop
for key,value in mydict.items():
    print(key, "=>", value)
# Out:
# before update {'id': '59912', 'name': 'AAA', 'location': 'bengaluru'}
# after update {'id': '59912', 'name': 'AAA', 'location': 'bengaluru', 'Salary': 899999}
# id => 59912
# name => AAA
# location => bengaluru
# Salary => 899999
