# %%
randomList=['a',0,2]
for item in randomList:
        print("An item is ",item)
        res=1/int(item)
        print(res)
        break
print("Outside the for loop")
# Out:
# An item is  a
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 4
#       2 for item in randomList:
#       3         print("An item is ",item)
# ----> 4         res=1/int(item)
#       5         print(res)
#       6         break
#
# ValueError: invalid literal for int() with base 10: 'a'

# %%
randomList=['a',0,2]
for item in randomList:
    try:
        print("An item is ",item)
        res=1/int(item)
        print(res)
        break
    except:
        print("Oops ! there is an error")
print("Outside the for loop")
# Out:
# An item is  a
# Oops ! there is an error
# An item is  0
# Oops ! there is an error
# An item is  2
# 0.5
# Outside the for loop

# %%
import sys
randomList=['a',0,2]
for item in randomList:
    try:
        print("An item is ",item)
        res=1/int(item)
        print(res)
        break
    except:
        #print(sys.exc_info())
        print("Oops ! ",sys.exc_info()[0]," occurred.")
print("Outside the for loop")
# Out:
# An item is  a
# Oops !  <class 'ValueError'>  occurred.
# An item is  0
# Oops !  <class 'ZeroDivisionError'>  occurred.
# An item is  2
# 0.5
# Outside the for loop

# %%
randomList=['a',0,2]
for item in randomList:
    try:
        print("An item is ",item)
        res=1/int(item)
        print(res)
        break
    except ValueError:
        print("Oops ! there is an error")
    except ZeroDivisionError:
        print("Division by zero is not allowed")
print("Outside the for loop")
# Out:
# An item is  a
# Oops ! there is an error
# An item is  0
# Division by zero is not allowed
# An item is  2
# 0.5
# Outside the for loop

# %%
import sys
randomList=['a',0,2]
for item in randomList:
    try:
        print("An item is ",item)
        res=1/int(item)
        print(res)
        break
    except (ValueError,ZeroDivisionError):
        print("Oops ! there is an error ",sys.exc_info()[0]," occurred.")
    
print("Outside the for loop")
# Out:
# An item is  a
# Oops ! there is an error  <class 'ValueError'>  occurred.
# An item is  0
# Oops ! there is an error  <class 'ZeroDivisionError'>  occurred.
# An item is  2
# 0.5
# Outside the for loop

# %%
try:
    num = int(input("Enter a positive integer: "))
    if num<=0:
        raise ValueError("Number entered is not positive integer")
    else:
        print("Number entered is positive integer")
except ValueError as ve:
    print(ve)
# Out:
# Enter a positive integer:  -10
# Number entered is not positive integer

# %%
try:
    file= open("D:\\bizschoolpython\\2026\\story.txt")
    #raise ErrorName
    print(file.read())
except FileNotFoundError as fe:
    print(fe)
finally:
    file.close()
    #file.write("Hello")
# Out:
# Mary had a little lamb.
# His fleece was white as snow,
# and everywhere that Mary went
# the lamb was sure to go.

# %%
'''
Object --  A real world object For ex - employee,student,customer
In Object Oriented programming we need this object
For Example :
employee will have properties like employee id, name,department,address,salary
 behavior of real world object can depicted by functions
student object properties - id,name,rollno,courses enrolled,batchno
customer - id,name,address
car - model,color,transmission,yearOfMfg
shape- length,breadth -- is propete
       area() -- function -- means behaviour
In programming world: there is a class which is a blueprint of a real world objects

'''
'''
    Key Components
    class keyword: Used to create a new class.
    Attributes: Variables associated with a class or its instances or objects.
                Class attributes are shared by all instances or objects (e.g., empId and empName in the example).
    Instance attributes are unique to each object and are typically defined within the __init__ method using the self keyword (e.g., eId and eName).
    __init__ method: A special "dunder" (double underscore) method that acts as a constructor. It is automatically called when a new object is created and is used to initialize the object's state.
    self parameter: The first parameter in all instance methods, conventionally named self. It is a reference to the current object instance, allowing methods to access and modify that specific object's attributes. Python passes this argument automatically when a method is called.
    Methods: Functions defined inside a class that describe the behaviors or actions an object can perform. 
'''
class Employee:
    #variables or attributes or properties of the Employee class
    empId = 0
    empName =''
    #Constructor method, runs automatically when a new object is created
    def __init__(self,eId,eName):
        self.empId=eId
        self.empName=eName       

    #Functions
    def display(self):
        print("Employee id is : ",self.empId," and Employee name is : ",self.empName)
     
    pass #pass is a placeholder

emp =Employee(15,'Vishnu') #Here emp is an object of Employee type, We are calling Employee() constructor to creat an object
print(emp)
print(emp.empId) #accessing the properties or variables using an object or instance
print(emp.empName)
emp.display() #Calling function of a class using an object or instance
# Out:
# ...
# 15
# Vishnu
# Employee id is :  15  and Employee name is :  Vishnu

# %%
class Employee:
    empId=0
    empName=''
    salary=0.0
    address=''

    def __init__(self,eId,eName,salary,address):
        self.empId=eId
        self.empName=eName
        self.salary=salary
        self.address=address
    def employeeDetails(self):
        return "Employee id is "+str(self.empId)+"\nEmployee name is "+self.empName+"\nEmployee salary is "+str(self.salary)+"\nEmployee address is "+self.address

#Various objects of Employee Class
emp1=Employee(11,'John',1555.50,'BLR')
emp2=Employee(12,'Bill',2555.00,'CHN')
emp3=Employee(13,'Babu',1454.50,'HYD')
emp4=Employee(14,'Raja',1115.00,'Vizag')
emp5=Employee(15,'Yash',5556.10,'KGF')

employees=[emp1,emp2,emp3,emp4,emp5]
for e in employees:
    print(22 * "*")
    print(e.employeeDetails())
# Out:
# **********************
# Employee id is 11
# Employee name is John
# Employee salary is 1555.5
# Employee address is BLR
# **********************
# Employee id is 12
# Employee name is Bill
# Employee salary is 2555.0
# Employee address is CHN
# **********************
# Employee id is 13
# Employee name is Babu
# Employee salary is 1454.5
# Employee address is HYD
# **********************
# Employee id is 14
# Employee name is Raja
# Employee salary is 1115.0
# Employee address is Vizag
# **********************
# Employee id is 15
# Employee name is Yash
# Employee salary is 5556.1
# Employee address is KGF

# %%
#Define a custom Exception named as EmployeeNotFoundException
#Here EmployeeNotFoundException is an user defined or custom exception class. Where as Exception is built in class provided in Python
class EmployeeNotFoundException(Exception):
    pass #pass is a placeholder 
#Find an employee with a given id from employees list
def findEmpById(eId):
        for emp in employees:
            if(emp.empId == eId):
                print("Employee with id "+str(eId)+" found")
                #print(emp.employeeDetails())
                #break
                return emp
        raise EmployeeNotFoundException("Employee with id "+str(eId)+" not found")
try:
    findEmpById(11111)
except EmployeeNotFoundException as e:
    print(e)
# Out:
# Employee with id 11111 not found

# %%
class EmployeeNotFoundException(Exception):
    def __init__(self, message):
        super().__init__(message)


class Employee:
    empId = 0
    empName = ''
    salary = 0.0
    address = ''

    def __init__(self, eId, eName, salary, address):
        self.empId = eId
        self.empName = eName
        self.salary = salary
        self.address = address

    def employeeDetails(self):
        return "Employee id is " + str(self.empId) + \
               "\nEmployee name is " + self.empName + \
               "\nEmployee salary is " + str(self.salary) + \
               "\nEmployee address is " + self.address


# Various objects of Employee Class
emp1 = Employee(11, 'John', 1555.50, 'BLR')
emp2 = Employee(12, 'Bill', 2555.00, 'CHN')
emp3 = Employee(13, 'Babu', 1454.50, 'HYD')
emp4 = Employee(14, 'Raja', 1115.00, 'Vizag')
emp5 = Employee(15, 'Yash', 5556.10, 'KGF')

employees = [emp1, emp2, emp3, emp4, emp5]


# Function to search employee
def find_employee(empId):
    for emp in employees:
        if emp.empId == empId:
            return emp
    raise EmployeeNotFoundException(f"Employee with ID {empId} not found")


# Display all employees
for e in employees:
    print(22 * "*")
    print(e.employeeDetails())


# Search employee
try:
    search_id = int(input("\nEnter Employee ID to search: "))
    emp = find_employee(search_id)
    print("\nEmployee Found:")
    print(emp.employeeDetails())

except EmployeeNotFoundException as e:
    print("\nException:", e)
# Out:
# **********************
# Employee id is 11
# Employee name is John
# Employee salary is 1555.5
# Employee address is BLR
# **********************
# Employee id is 12
# Employee name is Bill
# Employee salary is 2555.0
# Employee address is CHN
# **********************
# Employee id is 13
# Employee name is Babu
# Employee salary is 1454.5
# Employee address is HYD
# **********************
# Employee id is 14
# Employee name is Raja
# Employee salary is 1115.0
# Employee address is Vizag
# **********************
# Employee id is 15
# Employee name is Yash
# Employee salary is 5556.1
# Employee address is KGF
# Enter Employee ID to search:  1111
# Exception: Employee with ID 1111 not found

# %%
#User defined exception
class Error(Exception):
    """
        Base class for other exceptions
    """
    pass
class ValueTooSmallError(Error):
    '''
        Raised when the input value is too small
    '''
    pass
class ValueTooLargeError(Error):
    '''
        Raised when the input value is too large
    '''
    pass

#Our main program
number=10
while True:
   try:
       i_num = int(input("Enter a number: "))
       if i_num < number:
           raise ValueTooSmallError
       elif i_num > number:
           raise ValueTooLargeError
       break
   except ValueTooSmallError:
       print("This value is too small, try again!")
       print()
   except ValueTooLargeError:
       print("This value is too large, try again!")
       print()
print("Congratulations! You guessed it correctly.")
# Out:
# Enter a number:  1
# This value is too small, try again!
# Enter a number:  1111
# This value is too large, try again!
# Enter a number:  10
# Congratulations! You guessed it correctly.

# %%
'''
Create a simple Banking System with the Main menu which lets
customer Create Account, View Account details, Withdraw
amount and deposit amount based on the option entered.
Write Program in Python using:
Object Oriented Programming (OOP)
Custom Exceptions
Menu Driven Program
The system allows a customer to:
1.Create Account
2.View Account Details
3.Deposit Money
4.Withdraw Money
5.Exit
'''
